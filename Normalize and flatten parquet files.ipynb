# %%
import json

# !pip install pandas pyarrow fastparquet
# Out:
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.12/site-packages (1.5.3)
# Requirement already satisfied: pyarrow in /databricks/python3/lib/python3.12/site-packages (15.0.2)
# Collecting fastparquet
#   Using cached fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /databricks/python3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Collecting cramjam>=2.3 (from fastparquet)
#   Using cached cramjam-2.9.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: fsspec in /databricks/python3/lib/python3.12/site-packages (from fastparquet) (2023.5.0)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from fastparquet) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Using cached fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
# Using cached cramjam-2.9.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.9.0 fastparquet-2024.11.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %python
import os
import pandas as pd
from azure.storage.blob import BlobServiceClient

# Initialize the Blob Service Client
connection_string = "account key"
container_name = "group2"
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
container_client = blob_service_client.get_container_client(container_name)



# Function for safe JSON parsing
def safe_json_loads(x):
    try:
        return json.loads(x) if isinstance(x, str) else x
    except json.JSONDecodeError:
        return None  # Return None for invalid JSON strings


input_folder = "Decoded data in parquet format/JuneMachineData_decoded"
output_folder = "Normalized data in parquet format/JuneMachineData_normalized"


# Iterate over all files in the input folder
blobs = container_client.list_blobs(name_starts_with=input_folder)

for blob in blobs:
    blob_name = blob.name
    print(f"Processing blob: {blob_name}")
    
    try:
        # Download the blob to a temporary file
        temp_file_path = "temp_file.parquet"
        normalized_file_path = None  # Initialize normalized_file_path

        with open(temp_file_path, "wb") as temp_file:
            blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
            temp_file.write(blob_client.download_blob().readall())

        # Read the Parquet file into a Pandas DataFrame
        df = pd.read_parquet(temp_file_path, engine='fastparquet')

        # Safely parse the 'BodyContent' column and flatten it
        df['BodyContent'] = df['BodyContent'].apply(safe_json_loads)
        body_content_df = pd.json_normalize(df['BodyContent'].explode())
        df_flattened = df.drop(['BodyContent'], axis=1).join(body_content_df)

        # Save the normalized DataFrame locally in Parquet format
        normalized_file_path = f"normalized_{os.path.basename(blob_name)}"
        df_flattened.to_parquet(normalized_file_path, index=False)

        # Define the output blob name
        output_blob_name = f"{output_folder}/{os.path.basename(normalized_file_path)}"

        # Upload the normalized file to the output folder in Blob Storage
        with open(normalized_file_path, "rb") as data:
            container_client.upload_blob(name=output_blob_name, data=data, overwrite=True)

        print(f"File '{normalized_file_path}' successfully uploaded to '{output_blob_name}'.")

    except Exception as e:
        print(f"Error processing {blob_name}: {e}")
    
    finally:
        # Clean up temporary files
        if os.path.exists(temp_file_path):
            os.remove(temp_file_path)
        if normalized_file_path and os.path.exists(normalized_file_path):
            os.remove(normalized_file_path)

print("Processing completed.")
# Out:
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded
# Error processing Decoded data in parquet format/JuneMachineData_decoded: [Errno 22] Invalid argument
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June1.parquet
# File 'normalized_June1.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June1.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June10.parquet
# File 'normalized_June10.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June10.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June100.parquet
# File 'normalized_June100.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June100.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June101.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June101.parquet: [Errno 2] No such file or directory: 'temp_file.parquet'
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June102.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June102.parquet: File parse failed: None
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June103.parquet
# File 'normalized_June103.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June103.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June104.parquet
# File 'normalized_June104.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June104.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June105.parquet
# File 'normalized_June105.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June105.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June106.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June106.parquet: File parse failed: None
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June107.parquet
# File 'normalized_June107.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June107.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June108.parquet
# File 'normalized_June108.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June108.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/
parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June683.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June684.parquet
# File 'normalized_June684.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June684.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June685.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June685.parquet: [Errno 22] Invalid argument
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June686.parquet
# File 'normalized_June686.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June686.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June687.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June687.parquet: [Errno 2] No such file or directory: 'temp_file.parquet'
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June688.parquet
# File 'normalized_June688.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June688.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June689.parquet
# File 'normalized_June689.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June689.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June69.parquet
# File 'normalized_June69.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June69.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June690.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June690.parquet: [Errno 2] No such file or directory: 'temp_file.parquet'
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June691.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June691.parquet: [Errno 22] Invalid argument
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June692.parquet
# File 'normalized_June692.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June692.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June693.parquet
# File 'normalized_June693.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June693.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June694.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June694.parquet: [Errno 2] No such file or directory: 'temp_file.parquet'
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June695.parquet
# File 'normalized_June695.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June695.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June696.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June696.parquet: [Errno 2] No such file or directory: 'temp_file.parquet'
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June697.parquet
# File 'normalized_June697.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June697.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June698.parquet
# File 'normalized_June698.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June698.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June699.parquet
# File 'normalized_June699.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June699.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June7.parquet
# File 'normalized_June7.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June7.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June70.parquet
# File 'normalized_June70.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June70.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June700.parquet
# File 'normalized_June700.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June700.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June701.parquet
# File 'normalized_June701.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June701.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June702.parquet
# File 'normalized_June702.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June702.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June703.parquet
# File 'normalized_June703.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June703.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June704.parquet
# File 'normalized_June704.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June704.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June705.parquet
# File 'normalized_June705.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June705.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June706.parquet
# File 'normalized_June706.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June706.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June707.parquet
# File 'normalized_June707.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June707.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June708.parquet
# File 'normalized_June708.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June708.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June709.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June709.parquet: [Errno 22] Invalid argument
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June71.parquet
# File 'normalized_June71.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June71.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June710.parquet
# File 'normalized_June710.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June710.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June711.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June711.parquet: [Errno 2] No such file or directory: 'temp_file.parquet'
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June712.parquet
# File 'normalized_June712.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June712.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June72.parquet
# File 'normalized_June72.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June72.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June73.parquet
# File 'normalized_June73.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June73.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June74.parquet
# File 'normalized_June74.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June74.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June75.parquet
# File 'normalized_June75.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June75.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June76.parquet
# File 'normalized_June76.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June76.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June77.parquet
# File 'normalized_June77.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June77.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June78.parquet
# File 'normalized_June78.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June78.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June79.parquet
# File 'normalized_June79.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June79.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June8.parquet
# File 'normalized_June8.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June8.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June80.parquet
# File 'normalized_June80.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June80.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June81.parquet
# File 'normalized_June81.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June81.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June82.parquet
# File 'normalized_June82.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June82.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June83.parquet
# File 'normalized_June83.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June83.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June84.parquet
# File 'normalized_June84.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June84.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June85.parquet
# File 'normalized_June85.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June85.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June86.parquet
# File 'normalized_June86.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June86.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June87.parquet
# File 'normalized_June87.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June87.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June88.parquet
# File 'normalized_June88.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June88.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June89.parquet
# File 'normalized_June89.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June89.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June9.parquet
# File 'normalized_June9.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June9.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June90.parquet
# File 'normalized_June90.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June90.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June91.parquet
# File 'normalized_June91.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June91.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June92.parquet
# Error processing Decoded data in parquet format/JuneMachineData_decoded/June92.parquet: [Errno 2] No such file or directory: 'temp_file.parquet'
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June93.parquet
# File 'normalized_June93.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June93.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June94.parquet
# File 'normalized_June94.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June94.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June95.parquet
# File 'normalized_June95.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June95.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June96.parquet
# File 'normalized_June96.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June96.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June97.parquet
# File 'normalized_June97.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June97.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June98.parquet
# File 'normalized_June98.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June98.parquet'.
# Processing blob: Decoded data in parquet format/JuneMachineData_decoded/June99.parquet
# File 'normalized_June99.parquet' successfully uploaded to 'Normalized data in parquet format/JuneMachineData_normalized/normalized_June99.parquet'.
# Processing completed.
